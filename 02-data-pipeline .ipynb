# %%
import numpy as np
import tensorflow as tf 
import matplotlib.pyplot as plt 
import cv2 
import utils 

# %matplotlib inline

# %% [markdown]
# # Example run of data pipeline

# %%
img = utils.Image('data/beach/beach01.jpg')

# %%
plt.imshow(cv2.cvtColor(img.data_nopadding, cv2.COLOR_BGR2RGB))

# %%
X, y = utils.img_to_dataset(img, window_size=7, squeeze=False)

# %%
X.shape, y.shape
# Out:
# ((10000, 7, 7), (10000, 3))
